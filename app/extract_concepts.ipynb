# %% [markdown]
# ## Setup

# %%
import pandas as pd
import numpy as np
import os
from langchain.document_loaders import PyPDFLoader, UnstructuredPDFLoader, PyPDFium2Loader
from langchain.document_loaders import PyPDFDirectoryLoader
from langchain.text_splitter import RecursiveCharacterTextSplitter
from pathlib import Path

# %% [markdown]
# ## Load Documents

# %%
documents = PyPDFLoader("data_input/practice-standard-project-risk-management.pdf").load()

splitter = RecursiveCharacterTextSplitter(
    chunk_size=1000,
    chunk_overlap=50,
    length_function=len,
    is_separator_regex=False,
)

pages = splitter.split_documents(documents)
print("Number of chunks = ", len(pages))
# Out:
# Number of chunks =  310

# %% [markdown]
# ## Create a dataframe of all the chunks

# %%
from helpers.df_helpers import documents2Dataframe
df = documents2Dataframe(pages)
print(df.shape)
df.head()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 from helpers.df_helpers import documents2Dataframe
#       2 df = documents2Dataframe(pages)
#       3 print(df.shape)
#
# ModuleNotFoundError: No module named 'helpers.df_helpers'

# %% [markdown]
# ## Extract Concepts

# %%
## This function uses the helpers/prompt function to extract concepts from text
from helpers.df_helpers import df2ConceptsList
from helpers.df_helpers import concepts2Df

# %%
concepts_list = df2ConceptsList(df[10:20])
# Out:
#  [
#       {
#           "entity": "Plan Risk Management Process",
#           "importance": 5,
#           "category": "event"
#       },
#       {
#           "entity": "Purpose and Objectives of the Plan Risk Management Process",
#           "importance": 4.1,
#           "category": "misc"
#       },
#       {
#           "entity": "Critical Success Factors for the Plan Risk Management Process",
#           "importance": 4.2,
#           "category": "concept"
#       },
#       {
#           "entity": "Barriers to Successful Project Risk Management",
#           "importance": 4.2.1,
#           "category": "condition"
#       },
#       {
#           "entity": "Project Stakeholders",
#           "importance": 4.2.2,
#           "category": "organisation"
#       },
#       {
#           "entity": "Organization’s Objectives, Policies, and Practices",
#           "importance": 4.2.3,
#           "category": "misc"
#       },
#       {
#           "entity": "Tools and Techniques for the Plan Risk Management Process",
#           "importance": 4.3,
#           "category": "concept"
#       },
#       {
#           "entity": "Planning Sessions",
#           "importance": 4.3.1,
#           "category": "object"
#       },
#       {
#           "entity": "Templates",
#           "importance": 4.3.2,
#           "category": "document"
#       },
#       {
#           "entity": "Documenting the Results of the Plan Risk Management Process",
#           "importance": 4.4,
#           "category": "event"
#       }
#    ]
#
# ERROR ### Here is the buggy response:   [
#       {
#           "entity": "Plan Risk Management Process",
#           "importance": 5,
#           "category": "event"
#       },
#       {
#           "entity": "Purpose and Objectives of the Plan Risk Management Process",
#           "importance": 4.1,
#           "category": "misc"
#       },
#       {
#           "entity": "Critical Success Factors for the Plan Risk Management Process",
#           "importance": 4.2,
#           "category": "concept"
#       },
#       {
#           "entity": "Barriers to Successful Project Risk Management",
#           "importance": 4.2.1,
#           "category": "condition"
#       },
#       {
#           "entity": "Project Stakeholders",
#           "importance": 4.2.2,
#           "category": "organisation"
#       },
#       {
#           "entity": "Organization’s Objectives, Policies, and Practices",
#           "importance": 4.2.3,
#           "category": "misc"
#       },
#       {
#           "entity": "Tools and Techniques for the Plan Risk Management Process",
#           "importance": 4.3,
#           "category": "concept"
#       },
#       {
#           "entity": "Planning Sessions",
#           "importance": 4.3.1,
#           "category": "object"
#       },
#       {
#           "entity": "Templates",
#           "importance": 4.3.2,
#           "category": "document"
#       },
#       {
#           "entity": "Documenting the Results of the Plan Risk Management Process",
#           "importance": 4.4,
#           "category": "event"
#       }
#    ]
#
#
#  [
#       {
#           "entity": "Project Management Institute",
#           "importance": 3,
#           "category": "organisation"
#       },
#       {
#           "entity": "Practice Standard for Project Risk Management",
#           "importance": 5,
#           "category": "document"
#       },
#       {
#           "entity": "Identify Risks Process",
#           "importance": 4,
#           "category": "process"
#       },
#       {
#           "entity": "Early Identification",
#           "importance": 3,
#           "category": "concept"
#       },
#       {
#           "entity": "Iterative Identification",
#           "importance": 3,
#           "category": "concept"
#       },
#       {
#           "entity": "Emergent Identification",
#           "importance": 3,
#           "category": "concept"
#       },
#       {
#           "entity": "Comprehensive Identification",
#           "importance": 3,
#           "category": "concept"
#       },
#       {
#           "entity": "Explicit Identification of Opportunities",
#           "importance": 3,
#           "category": "process"
#       }
#    ] [
#        {
#            "entity": "Multiple Perspectives",
#            "importance": 4,
#            "category": "concept"
#        },
#        {
#            "entity": "Project Objectives",
#            "importance": 4,
#            "category": "concept"
#        },
#        {
#            "entity": "Risks",
#            "importance": 5,
#            "category": "concept"
#        },
#        {
#            "entity": "Risk Statement",
#            "importance": 4,
#            "category": "concept"
#        },
#        {
#            "entity": "Ownership",
#            "importance": 3,
#            "category": "concept"
#        },
#        {
#            "entity": "Level of Detail",
#            "importance": 3,
#            "category": "concept"
#        },
#        {
#            "entity": "Objectivity",
#            "importance": 4,
#            "category": "concept"
#        },
#        {
#            "entity": "Tools and Techniques for Risk Identification",
#            "importance": 5,
#            "category": "event"
#        }
#    ] [
#        {
#            "entity": "Historical Review",
#            "importance": 4,
#            "category": "event"
#        },
#        {
#            "entity": "Current Assessments",
#            "importance": 4,
#            "category": "event"
#        },
#        {
#            "entity": "Creativity Techniques",
#            "importance": 3,
#            "category": "concept"
#        },
#        {
#            "entity": "Identify Risks Process Results Documentation",
#            "importance": 4,
#            "category": "document"
#        },
#        {
#            "entity": "Perform Qualitative Risk Analysis Process",
#            "importance": 5,
#            "category": "process"
#        },
#        {
#            "entity": "Purpose and Objectives of the Perform Qualitative Risk Analysis Process",
#            "importance": 4,
#            "category": "concept"
#        },
#        {
#            "entity": "Critical Success Factors for the Perform Qualitative Risk Analysis Process",
#            "importance": 4,
#            "category": "condition"
#        },
#        {
#            "entity": "Use Agreed-Upon Approach",
#            "importance": 3,
#            "category": "concept"
#        },
#        {
#            "entity": "Use Agreed-Upon Definitions of Risk Terms",
#            "importance": 3,
#            "category": "concept"
#        }
#    ] [
#       {
#           "entity": "Risks",
#           "importance": 5,
#           "category": "concept"
#       },
#       {
#           "entity": "Qualitative Risk Analysis",
#           "importance": 5,
#           "category": "concept"
#       },
#       {
#           "entity": "Risk Characteristics",
#           "importance": 4,
#           "category": "concept"
#       },
#       {
#           "entity": "Data Collection and Analysis",
#           "importance": 4,
#           "category": "event"
#       },
#       {
#           "entity": "Specific Objectives",
#           "importance": 3,
#           "category": "concept"
#       },
#       {
#           "entity": "Project",
#           "importance": 3,
#           "category": "concept"
#       },
#       {
#           "entity": "Risk Causes",
#           "importance": 3,
#           "category": "concept"
#       },
#       {
#           "entity": "Documentation",
#           "importance": 4,
#           "category": "document"
#       }
#    ] [
#     {
#         "entity": "Table of Contents",
#         "importance": 5,
#         "category": "concept"
#     },
#     {
#         "entity": "Document",
#         "importance": 5,
#         "category": "document"
#     }
# ] [
#     {
#        "entity": "Perform Quantitative Risk Analysis",
#        "importance": 5,
#        "category": "process"
#     },
#     {
#        "entity": "Project Management Institute",
#        "importance": 3,
#        "category": "organisation"
#     },
#     {
#        "entity": "Practice Standard for Project Risk Management",
#        "importance": 4,
#        "category": "document"
#     },
#     {
#        "entity": "Chapter 7 - PERFORM QUANTITATIVE RISK ANALYSIS",
#        "importance": 3,
#        "category": "concept"
#     },
#     {
#        "entity": "Purpose and Objectives of the Perform Quantitative Risk Analysis Process",
#        "importance": 4,
#        "category": "concept"
#     },
#     {
#        "entity": "Critical Success Factors for the Perform Quantitative Risk Analysis Process",
#        "importance": 4,
#        "category": "concept"
#     },
#     {
#        "entity": "Prior Risk Identification and Qualitative Risk Analysis",
#        "importance": 3,
#        "category": "process"
#     },
#     {
#        "entity": "Appropriate Project Model",
#        "importance": 2,
#        "category": "concept"
#     },
#     {
#        "entity": "Commitment to Collecting High Quality Risk Data",
#        "importance": 4,
#        "category": "condition"
#     },
#     {
#        "entity": "Unbiased Data",
#        "importance": 3,
#        "category": "concept"
#     },
#     {
#        "entity": "Overall Project Risk Derived from Individual Risks",
#        "importance": 4,
#        "category": "concept"
#     },
#     {
#        "entity": "Interrelationships Between Risks in Quantitative Risk Analysis",
#        "importance": 3,
#        "category": "concept"
#     }
# ] [
#       {
#           "entity": "Quantitative Risk Analysis Process",
#           "importance": 5,
#           "category": "event"
#       },
#       {
#           "entity": "Comprehensive Risk Representation",
#           "importance": 4,
#           "category": "concept"
#       },
#       {
#           "entity": "Risk Impact Calculation",
#           "importance": 4,
#           "category": "concept"
#       },
#       {
#           "entity": "Quantitative Method",
#           "importance": 4,
#           "category": "concept"
#       },
#       {
#           "entity": "Data Gathering Tools",
#           "importance": 3,
#           "category": "object"
#       },
#       {
#           "entity": "Effective Presentation of Quantitative Analysis Results",
#           "importance": 4,
#           "category": "concept"
#       },
#       {
#           "entity": "Iterative Quantitative Risk Analysis",
#           "importance": 3,
#           "category": "event"
#       },
#       {
#           "entity": "Information for Response Planning",
#           "importance": 3,
#           "category": "concept"
#       },
#       {
#           "entity": "Documenting the Results of the Perform Quantitative Risk Analysis Process",
#           "importance": 4,
#           "category": "event"
#       }
#    ] [
#       {
#           "entity": "Plan Risk Responses Process",
#           "importance": 5,
#           "category": "event"
#       },
#       {
#           "entity": "Purpose of Plan Risk Responses Process",
#           "importance": 4,
#           "category": "concept"
#       },
#       {
#           "entity": "Objectives of Plan Risk Responses Process",
#           "importance": 4,
#           "category": "concept"
#       },
#       {
#           "entity": "Communication",
#           "importance": 4,
#           "category": "condition"
#       },
#       {
#           "entity": "Risk-Related Roles and Responsibilities",
#           "importance": 4,
#           "category": "concept"
#       }
#    ] [
#       {
#           "entity": "Timing of Risk Responses",
#           "importance": 5,
#           "category": "concept"
#       },
#       {
#           "entity": "Resources for Responses",
#           "importance": 5,
#           "category": "concept"
#       },
#       {
#           "entity": "Budget for Responses",
#           "importance": 4,
#           "category": "concept"
#       },
#       {
#           "entity": "Schedule for Responses",
#           "importance": 4,
#           "category": "concept"
#       },
#       {
#           "entity": "Interaction of Risks and Responses",
#           "importance": 5,
#           "category": "concept"
#       },
#       {
#           "entity": "Appropriate Responses",
#           "importance": 5,
#           "category": "concept"
#       },
#       {
#           "entity": "Timely Responses",
#           "importance": 4,
#           "category": "concept"
#       },
#       {
#           "entity": "Effective Responses",
#           "importance": 5,
#           "category": "concept"
#       },
#       {
#           "entity": "Agreed-Upon Responses",
#           "importance": 4,
#           "category": "concept"
#       },
#       {
#           "entity": "Threats",
#           "importance": 5,
#           "category": "concept"
#       },
#       {
#           "entity": "Opportunities",
#           "importance": 5,
#           "category": "concept"
#       },
#       {
#           "entity": "Strategies for Responses",
#           "importance": 4,
#           "category": "concept"
#       }
#    ]

# %%
dfne = concepts2Df(concepts_list)
dfne.head()
# Out:
#                                           entity  importance      category  \
# 0                   project management institute         4.0  organisation
# 1  practice standard for project risk management         5.0      document
# 2                         identify risks process         4.0       process
# 3                           early identification         3.0       concept
# 4                       iterative identification         3.0       concept
#
#                            chunk_id     type
# 0  ce38c53d7b4440198db4d6f8ed8a2555  concept
# 1  ce38c53d7b4440198db4d6f8ed8a2555  concept
# 2  ce38c53d7b4440198db4d6f8ed8a2555  concept
# 3  ce38c53d7b4440198db4d6f8ed8a2555  concept
# 4  ce38c53d7b4440198db4d6f8ed8a2555  concept

# %%
dfne.shape
# Out:
# (814, 5)

# %% [markdown]
# ### Write CSV to an output directory

# %% [markdown]
# Both the dataframes are written in the csv format so we dont have to calculate them again.
#
#         dfne = dataframe of names entities
#
#         df = dataframe of chunks

# %%
out_dir = 'data_output'
outputdirectory = Path(f"{out_dir}")
if not os.path.exists(outputdirectory):
   os.makedirs(outputdirectory)
dfne.to_csv(outputdirectory/"concepts.csv", sep="|", index=False)
df.to_csv(outputdirectory/"chunks.csv", sep="|", index=False)
